# %%
from skimage.measure import compare_ssim as ssim
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import os.path

def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.mean((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
 
def compare_images(imageA, imageB, title):
	# compute the mean squared error and structural similarity
	# index for the images
	m = mse(imageA, imageB)
	s = ssim(imageA, imageB,multichannel=True)
 
	# setup the figure
	fig = plt.figure(title)
	plt.suptitle("MSE: %.6f, SSIM: %.4f" % (m, s))
 
	# show first image
	ax = fig.add_subplot(1, 2, 1)
	plt.imshow(imageA, cmap = plt.cm.gray)
	plt.axis("off")
 
	# show the second image
	ax = fig.add_subplot(1, 2, 2)
	plt.imshow(imageB, cmap = plt.cm.gray)
	plt.axis("off") 
    # show the images
	SAVE_DIR='/home/daniel/PredNet_artigo_jamc/kitti_results/prediction_plots_artigo_jamc_finetunned_scores/'
	plt.savefig(SAVE_DIR+title,dpi=300,bbox_inches='tight')
	plt.close()
	print 'saving!!'

DATA_DIR='/home/daniel/PredNet_artigo_jamc/kitti_results/prediction_plots_artigo_jamc_finetunned/'
DATA_DIR_2='/home/daniel/PredNet_artigo_jamc/kitti_results/prediction_plots_artigo_jamc_finetunned/'
obs = glob(DATA_DIR_2+'obs_*_*') 
pred = glob(DATA_DIR_2+'pred_*_*')
obs = sorted(obs)
pred= sorted(pred)
obs_pred = zip(obs,pred)


for each_obs, each_pred in obs_pred:
    name_obs = os.path.basename(each_obs)
    current_frame_index = name_obs[6:7]
    if current_frame_index == '0':
        previous_frame_index = 0
    else:
        previous_frame_index = int(current_frame_index) - 1
    new_file_name = name_obs[0:6]
    #name_prev = os.path.basename()
    #name_pred = os.path.basename(each_pred)
    name_file =  new_file_name + str(current_frame_index) + '_' + new_file_name + str(previous_frame_index) + '.png'   
    obs_processing = io.imread(DATA_DIR_2 + new_file_name + str(current_frame_index)+'.png')
    pred_processing = io.imread(DATA_DIR_2 + new_file_name + str(previous_frame_index)+'.png')
    compare_images(obs_processing,pred_processing,str(name_file))
    print 'image: '+str(name_file)+' saved!' 


print 'Pronto =)'
#fazer outro loop, mais fácil
# Out:
# obs_0_
# saving!!
# image: obs_0_0_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_1_obs_0_0.png saved!
# obs_0_
# saving!!
# image: obs_0_2_obs_0_1.png saved!
# obs_0_
# saving!!
# image: obs_0_3_obs_0_2.png saved!
# obs_0_
# saving!!
# image: obs_0_4_obs_0_3.png saved!
# obs_0_
# saving!!
# image: obs_0_5_obs_0_4.png saved!
# obs_0_
# saving!!
# image: obs_0_6_obs_0_5.png saved!
# obs_0_
# saving!!
# image: obs_0_7_obs_0_6.png saved!
# obs_0_
# saving!!
# image: obs_0_8_obs_0_7.png saved!
# obs_0_
# saving!!
# image: obs_0_9_obs_0_8.png saved!
# obs_1_
# saving!!
# image: obs_1_0_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_1_obs_1_0.png saved!
# obs_1_
# saving!!
# image: obs_1_2_obs_1_1.png saved!
# obs_1_
# saving!!
# image: obs_1_3_obs_1_2.png saved!
# obs_1_
# saving!!
# image: obs_1_4_obs_1_3.png saved!
# obs_1_
# saving!!
# image: obs_1_5_obs_1_4.png saved!
# obs_1_
# saving!!
# image: obs_1_6_obs_1_5.png saved!
# obs_1_
# saving!!
# image: obs_1_7_obs_1_6.png saved!
# obs_1_
# saving!!
# image: obs_1_8_obs_1_7.png saved!
# obs_1_
# saving!!
# image: obs_1_9_obs_1_8.png saved!
# obs_2_
# saving!!
# image: obs_2_0_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_1_obs_2_0.png saved!
# obs_2_
# saving!!
# image: obs_2_2_obs_2_1.png saved!
# obs_2_
# saving!!
# image: obs_2_3_obs_2_2.png saved!
# obs_2_
# saving!!
# image: obs_2_4_obs_2_3.png saved!
# obs_2_
# saving!!
# image: obs_2_5_obs_2_4.png saved!
# obs_2_
# saving!!
# image: obs_2_6_obs_2_5.png saved!
# obs_2_
# saving!!
# image: obs_2_7_obs_2_6.png saved!
# obs_2_
# saving!!
# image: obs_2_8_obs_2_7.png saved!
# obs_2_
# saving!!
# image: obs_2_9_obs_2_8.png saved!
# obs_3_
# saving!!
# image: obs_3_0_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_1_obs_3_0.png saved!
# obs_3_
# saving!!
# image: obs_3_2_obs_3_1.png saved!
# obs_3_
# saving!!
# image: obs_3_3_obs_3_2.png saved!
# obs_3_
# saving!!
# image: obs_3_4_obs_3_3.png saved!
# obs_3_
# saving!!
# image: obs_3_5_obs_3_4.png saved!
# obs_3_
# saving!!
# image: obs_3_6_obs_3_5.png saved!
# obs_3_
# saving!!
# image: obs_3_7_obs_3_6.png saved!
# obs_3_
# saving!!
# image: obs_3_8_obs_3_7.png saved!
# obs_3_
# saving!!
# image: obs_3_9_obs_3_8.png saved!
# Pronto =)
